# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By

# Set up the options for the Chrome WebDriver
chrome_options = Options()
chrome_options.add_argument("--headless")  # Run Chrome in headless mode (no GUI)

# Create a new instance of the Chrome WebDriver
driver = webdriver.Chrome(options=chrome_options)

# URL of the webpage
url = "https://www.youtube.com/"

# Open the webpage
driver.get(url)

# Wait for the page to load (you might need to adjust the time based on your internet speed)
driver.implicitly_wait(10)

# Get all text from the page
all_text_elements = driver.find_elements(By.TAG_NAME, "body")

# Iterate through the elements and get text
all_text = [element.text for element in all_text_elements]

# Print or use the text as needed
print(all_text)

# Close the WebDriver
driver.quit()
# Out:
# ['BD\nসাইন-ইন করুন\nহোম\nShorts\nসদস্যতা\nআপনি\nইতিহাস\nসবগুলি\nখবর\nমিউজিক\nলাইভ\nগেমিং\nসিটকম\nঅ্যানিমেশন\nপর্যটন\nকার্টুন\nফ্যামিলি প্ল্যান কিনুন। বাড়ির সর্বাধিক ৬ জন মেম্বারের জন্য ব্যাকগ্রাউন্ডে বিজ্ঞাপন ছাড়া মিউজিক।\nডাউনলোড করুন\nসূরা আর রহমান (الرحمن) - মন জুড়ানো তেলাওয়াত | Zain Abu Kautsar\nSundar Quran Tilawat\n10 লাটি ভিউ\n1 মাস আগে এ স্ট্রীম হয়েছে\nFull Highlights | India Vs Australia ICC World Cup 2023 Final | IND VS AUS Final Full Highlights\nHorsepower Pakistan\n7.7 লাটি ভিউ\n7 ঘন্টা আগে\nবেগম পাড়ায় ছাত্রলীগ নেতার বাড়ি! এতো টাকা পেলেন কোথায়? | Canada | Begum Para | Channel 24\nChannel 24\n4.8 লাটি ভিউ\n12 ঘন্টা আগে\nসর্ষের খোলের তরল সার ব্যবহারের সঠিক পদ্ধতি।গাছের বৃদ্ধি ও ফল ধরবে কয়েকগুণ। Mustard cake Fertilizer.\nLifeLens\n461টি ভিউ\n1 দিন আগে\nShorts\n"The Radiant Charm & Beauty of Zehra Gunes: Turkey\'s Volleyball Darling" #zehra #viral #trending\n43 লাটি ভিউ\nAnushka Sharma\'s Cute & Funny Edit with Virat Kohli 😍😂❤️\n1.4 কোটি ভিউ\nThe Aggarwal Sisters 😍😘🥰 #KajalAggarwal #NishaAggarwal #Kajal #KajalFans #Kajalism #Kafawa\n2.7 কোটি ভিউ\nআরও দেখুন\nBAGIRA " New 2023 Released Full Hindi Dubbed Action Movie | Superstar Ravi Teja New Film\nGlosi Movie\n35 লাটি ভিউ\n12 দিন আগে\nVASTE | DVANI | NEW SONG | LOVE STORY SONG | DSU BOY | NEW SONG 2023\nDSU BOY \n1 কোটি ভিউ\n9 মাস আগে\nএখন জনপ্রিয়\nতফসিল প্রসঙ্গে ব্যারিস্টার আন্দালিব রহমান পার্থের বক্তব্য | চ্যানেল আই\nChannel i Shows\n29 লাটি ভিউ\n4 দিন আগে\nনির্বাচন, না মনোনয়ন\nDW খালেদ মুহিউদ্দীন জানতে চায়\n10 লাটি ভিউ\n2 দিন আগে এ স্ট্রীম হয়েছে\nআরও দেখুন\n৫০০ মিলিয়ন ড
# %%
cleaned_text = '\n'.join(line.strip() for line in '\n'.join(all_text).splitlines() if line.strip())
print(cleaned_text)
# Out:
# BD
# সাইন-ইন করুন
# হোম
# Shorts
# সদস্যতা
# আপনি
# ইতিহাস
# সবগুলি
# খবর
# মিউজিক
# লাইভ
# গেমিং
# সিটকম
# অ্যানিমেশন
# পর্যটন
# কার্টুন
# ফ্যামিলি প্ল্যান কিনুন। বাড়ির সর্বাধিক ৬ জন মেম্বারের জন্য ব্যাকগ্রাউন্ডে বিজ্ঞাপন ছাড়া মিউজিক।
# ডাউনলোড করুন
# সূরা আর রহমান (الرحمن) - মন জুড়ানো তেলাওয়াত | Zain Abu Kautsar
# Sundar Quran Tilawat
# 10 লাটি ভিউ
# 1 মাস আগে এ স্ট্রীম হয়েছে
# Full Highlights | India Vs Australia ICC World Cup 2023 Final | IND VS AUS Final Full Highlights
# Horsepower Pakistan
# 7.7 লাটি ভিউ
# 7 ঘন্টা আগে
# বেগম পাড়ায় ছাত্রলীগ নেতার বাড়ি! এতো টাকা পেলেন কোথায়? | Canada | Begum Para | Channel 24
# Channel 24
# 4.8 লাটি ভিউ
# 12 ঘন্টা আগে
# সর্ষের খোলের তরল সার ব্যবহারের সঠিক পদ্ধতি।গাছের বৃদ্ধি ও ফল ধরবে কয়েকগুণ। Mustard cake Fertilizer.
# LifeLens
# 461টি ভিউ
# 1 দিন আগে
# Shorts
# "The Radiant Charm & Beauty of Zehra Gunes: Turkey's Volleyball Darling" #zehra #viral #trending
# 43 লাটি ভিউ
# Anushka Sharma's Cute & Funny Edit with Virat Kohli 😍😂❤️
# 1.4 কোটি ভিউ
# The Aggarwal Sisters 😍😘🥰 #KajalAggarwal #NishaAggarwal #Kajal #KajalFans #Kajalism #Kafawa
# 2.7 কোটি ভিউ
# আরও দেখুন
# BAGIRA " New 2023 Released Full Hindi Dubbed Action Movie | Superstar Ravi Teja New Film
# Glosi Movie
# 35 লাটি ভিউ
# 12 দিন আগে
# VASTE | DVANI | NEW SONG | LOVE STORY SONG | DSU BOY | NEW SONG 2023
# DSU BOY
# 1 কোটি ভিউ
# 9 মাস আগে
# এখন জনপ্রিয়
# তফসিল প্রসঙ্গে ব্যারিস্টার আন্দালিব রহমান পার্থের বক্তব্য | চ্যানেল আই
# Channel i Shows
# 29 লাটি ভিউ
# 4 দিন আগে
# নির্বাচন, না মনোনয়ন
# DW খালেদ মুহিউদ্দীন জানতে চায়
# 10 লাটি ভিউ
# 2 দিন আগে এ স্ট্রীম হয়েছে
# আরও দেখুন
# ৫০০ মিলিয়ন ডলার সোনার বার ডাকাতি মিশন | Movie Explain in Bangla | Robbery | BD STORY Star
# BD STORY Star
# 42 হাটি ভিউ
# 10 দিন আগে
# দুইদিন অচেতন পুরো বাড়ির লোক, কী হয়েছিলো? | Keraniganj Thief | Dhaka News | Somoy TV
# SOMOY TV
# 3.1 লাটি ভিউ
# 20 ঘন্টা আগে
# দেখানো হয়েছে
# ডেঙ্গু প্রতিরোধে ও জীবন বাঁচাতে করণীয় সম্পর্কে জানুন।
# ডেঙ্গু প্রতিরোধের লড়াইয়ে আমাদের সাথে যুক্ত হোন।
# Symptoms of Dengue | DG of DGHS | UNICEF Bangladesh
# UNICEF Bangladesh
# Crucial tips to prevent Dengue | UNICEF Bangladesh
# UNICEF Bangladesh
# আরও জানুন
# আরও দেখুন
# ভ্যাবিলন সভ্যতা ও মুসলিম জাতির পিতার ৪ হাজার ১৪ বছর আগের অবিস্মরণীয় ইতিহাস আবু ত্বহা মুহাম্মদ আদনান
# Abu Taw Haa Media
# 18 লাটি ভিউ
# 4 মাস আগে
# Kobitar Gaan(কবিতার গান) || Hasan Joy || Lyrics Song
# Hive Song
# 19 লাটি ভিউ
# 3 সপ্তাহ আগে
# আজ অনেক গাছ বসালাম। সুন্দর একটা হারভেসটিং ও করলাম।# chad krishi# rooftop garden# harvesting# chad
# অন্তিম পলির ছাদ বাগান
# 496টি ভিউ
# 1 দিন আগে
# টানেলে আটকে আছে ১৫ বাস; বাঁচার আশা নেই কারও! | South Korea Tunnel Disaster | JamunaTV
# Jamuna TV
# 33 লাটি ভিউ
# 4 মাস আগে
# সূরা আল বাকারা এর অত্যন্ত দরদী কন্ঠে তিলাওয়াত┇Surah Al Baqarah Recited by Abdul Rahman Al Rashoud
# An Nafee
# 2.2 কোটি ভিউ
# 2 বছর পূর্বে
# লন্ডভন্ড উত্তর ইসরায়েল | DBC News Special
# DBC NEWS
# 16 লাটি ভিউ
# 9 দিন আগে
# অস্ট্রেলিয়ার শ্রেষ্ঠত্বের পর্দা নামলো বিশ্বকাপে | WorldCup | SportsNews | Ekattor TV
# Ekattor TV
# 1.2 লাটি ভিউ
# 5 ঘন্টা আগে
# Desi Madam | দেশী ম্যাডাম | School Love | Niloy Alamgir | Heme | Mohin Khan | Bangla New Movie 2023
# Niloy Alamgir Natok
# 8.3 লাটি ভিউ
# 2 সপ্তাহ আগে
# তফসিল ঘোষণার পর ওবায়দুল কাদেরের বক্তব্য নিয়ে যা বললেন গোলাম মাওলা রনি | Golam Maula Rony | SATV
# SATV
# 3.1 লাটি ভিউ
# 7 ঘন্টা আগে
# কিসের এত দুঃখ তোমার সারাক্ষণ বসে বসে ভাবছো | Bangla old song jaems lrycs
# A Istar
# 58 লাটি ভিউ
# 5 মাস আগে
# নবীজির জীবনের কিছু বিস্ময়কর ঘটনা/মুফতী-নজরুল-ইসলাম-কাসেমী #ইসলামিক_লাইভ_ওয়াজ
# ISLAMIC LIVE WAZ
# 19 লাটি ভিউ
# 7 মাস আগে
# হেরে আম্পায়ার কেটেলবরোকে দুষছেন ভারতীয় দর্শকরা, মেডেল নেয়ার সময় পুরো স্টেডিয়াম জুড়ে দুয়োধ্বনি।
# Cricfrenzy
# 1.3 লাটি ভিউ
# 5 ঘন্টা আগে
