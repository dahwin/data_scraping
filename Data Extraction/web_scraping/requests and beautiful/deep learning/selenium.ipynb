# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By

# Set up the options for the Chrome WebDriver
chrome_options = Options()
chrome_options.add_argument("--headless")  # Run Chrome in headless mode (no GUI)

# Create a new instance of the Chrome WebDriver
driver = webdriver.Chrome(options=chrome_options)

# URL of the webpage
url = "https://www.quora.com/Is-Twice-getting-disbanded"

# Open the webpage
driver.get(url)

# Wait for the page to load (you might need to adjust the time based on your internet speed)
driver.implicitly_wait(10)

# Get all text from the page
all_text_elements = driver.find_elements(By.TAG_NAME, "body")

# Iterate through the elements and get text
all_text = [element.text for element in all_text_elements]

# Print or use the text as needed
# print(all_text)

# Close the WebDriver
driver.quit()

# %%
cleaned_text = '\n'.join(line.strip() for line in '\n'.join(all_text).splitlines() if line.strip())
print(cleaned_text)
# Out:
# Sign In
# Is Twice getting disbanded?
# Ad by MCW
# ICC ওয়ার্ল্ড কাপ ২০২৩ গিভওয়ে!
# এর সাথে বড় জয় লাভ করুন সর্বোচ্চ ৳২৫,০০০,০০০ টাকা পর্যন্ত পুরুষ্কার!
# Sign Up
# All related (35)
# Sort
# Recommended
# donutlia.
# 𝚞𝚕𝚝𝚜 𝚒𝚝𝚣𝚢 𝚊𝚗𝚍 𝚜𝚝𝚛𝚊𝚢 𝚔𝚒𝚍𝚜Author has 577 answers and 1M answer views1y
# I’m on my way up—
# Continue Reading
# 7
# Related questions
# More answers below
# When is Twice going to disband?
# Will TWICE be renewing their contract?
# How many times did TWICE almost get disbanded?
# What will happen if Twice disband?
# Is it true that Black Pink will disband in 2023? It's so sad.
# Eden W.
# Author has 70 answers and 284.3K answer views1y
# Nope! And they probably won’t anytime soon (by soon I mean within the year/next year).
# They just had their comeback
# Continue Reading
# 2
# Sponsored by Bajilive
# ৳১০,০০০ ইনস্ট্যান্ট রিলোড বোনাস৷.
# লাইভ ক্যাসিনো এবং টেবিল খেলুন, প্রতি সপ্তাহে ক্যাশব্যাক পান!
# Sign Up
# 130
# Han Gyeong Na
# goes to College and knows K-pop a lot ༼ つ ◕_◕ ༽つ👋Author has 69 answers and 57.8K answer views1y
# i don't mean to be rude but all i could say is, I'm not in the mood and i cant answer that now. i don't like to think they might actually disband so I'm going silent for a good luck; in their future career. my apologies but I'm going silent and positive at the same time
# 1
# Pankaj Gola
# Owner at ChopNewsAuthor has 3.8K answers and 3.1M answer viewsOct 19
# Continue Reading
# Related questions
# More answers below
# What would happen to TWICE if they disbanded?
# Is Twice disbanding in 2022?
# When do the BTS members’ contracts end?
# When is Stray Kids disbanding?
# Which member of Twice is going to leave?
# Teana Chan
# Author has 2.9K answers and 19.4M answer views1y
# Nope. They JUST dropped a new album “Between 1&2 and MV “Talk that Talk” a few days ago. They are currently promoting “Talk that Talk”.
# Plus on top of that, they ALL renewed their contracts with JYP back in July so that means they’ll be around for a least a few more years.
# All 9 Members Of TWICE Renew Contracts With JYP Entertainment
# All nine members of TWICE will be continuing with JYP Entertainment! On July 12, a representative of JYP Entertainment shared, “Ahead of the expiration of their exclusive contracts this fall, all members of TWICE completed renewing their contracts. TWICE, who played a crucial role in establishing JYP’s status, and JYP, which became a reliable source
# https://www.soompi.com/article/1535323wpp/all-9-members-of-twice-renew-contracts-with-jyp-entertainment
# So no, they are not “getting disbanded” anytime soon.
# 1
# 1
# Sponsored by Six6s
# Six6s-এ ৳৬৬৬,৬৬৬ জিতুন.
# লিডারবোর্ড চ্যালেঞ্জ! আইসিসি বিশ্বকাপের সময় বিশাল বোনাস জিতুন!
# Learn More
# 56
# Related questions
# When is Twice going to disband?
# Will TWICE be renewing their contract?
# How many times did TWICE almost get disbanded?
# What will happen if Twice disband?
# Is it true that Black Pink will disband in 2023? It's so sad.
# What would happen to TWICE if they disbanded?
# Is Twice disbanding in 2022?
# When do the BTS members’ contracts end?
# When is Stray Kids disbanding?
# Which member of Twice is going to leave?
# When does Itzy’s contract with JYP end?
# Why are Blackpink not releasing another song?
# Is Lisa from BLACKPINK leaving the group?
# Which TWICE member will have the hardest time to survive if they disband?
# Will Blackpink disband in 2023 or 2025?
# Related questions
# When is Twice going to disband?
# Will TWICE be renewing their contract?
# How many times did TWICE almost get disbanded?
# What will happen if Twice disband?
# Is it true that Black Pink will disband in 2023? It's so sad.
# What would happen to TWICE if they disbanded?
# Advertisement
# AboutCareersPrivacyTermsContactLanguagesYour Ad ChoicesPress© Quora, Inc. 2023

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By

# Set up the options for the Chrome WebDriver
chrome_options = Options()
chrome_options.add_argument("--headless")  # Run Chrome in headless mode (no GUI)

# Create a new instance of the Chrome WebDriver
driver = webdriver.Chrome(options=chrome_options)

# URL of the webpage
url = "https://deepmind.google/discover/blog/transforming-the-future-of-music-creation/"

# Open the webpage
driver.get(url)

# Wait for the page to load (you might need to adjust the time based on your internet speed)
driver.implicitly_wait(10)

# Get all links from the page
all_links_elements = driver.find_elements(By.TAG_NAME, "a")

# Extract href attributes from the links
all_links = [link.get_attribute("href") for link in all_links_elements]

# Print or use the links as needed
print(all_links)

# Close the WebDriver
driver.quit()
# Out:
# ['https://deepmind.google/discover/blog/transforming-the-future-of-music-creation/#content', 'https://deepmind.google/', 'https://deepmind.google/search', 'https://deepmind.google/', 'https://deepmind.google/about/', 'https://deepmind.google/about/', 'https://deepmind.google/about/responsibility-safety/', 'https://deepmind.google/about/education/', 'https://deepmind.google/about/careers/', 'https://deepmind.google/about/press/', 'https://deepmind.google/technologies/', 'https://deepmind.google/impact/', 'https://deepmind.google/discover/', 'https://deepmind.google/discover/', 'https://deepmind.google/discover/blog/', 'https://deepmind.google/discover/the-podcast/', 'https://deepmind.google/discover/visualising-ai/', 'https://deepmind.google/search', 'https://www.facebook.com/sharer/sharer.php?u=https%3A//deepmind.google/discover/blog/transforming-the-future-of-music-creation/', 'https://twitter.com/intent/tweet?text=https%3A//deepmind.google/discover/blog/transforming-the-future-of-music-creation/', 'https://www.linkedin.com/shareArticle?url=https%3A//deepmind.google/discover/blog/transforming-the-future-of-music-creation/&mini=true', 'mailto:?subject=Transforming%20the%20future%20of%20music%20creation&body=https%3A//deepmind.google/discover/blog/transforming-the-future-of-music-creation/', 'https://blog.youtube/inside-youtube/ai-and-music-experiment/', 'https://blog.youtube/inside-youtube/partnering-with-the-music-industry-on-ai/', 'https://www.deepmind.com/synthid', 'https://cloud.google.com/vertex-ai/docs/generative-ai/image/overview', 'https://blog.youtube/inside-youtube/partnering-with-the-music-industry-on-ai/', 'https://blog.youtube/inside-youtube/ai-and-music-experiment/', 'https://deepmind.google/discover/blog/', 'https://deepmind.google/technologies/synthid/', 'https://deepmind.google/discover/blog/identifying-ai-generated-images-with-synthid/', 'https://twitter.com/googledeepmind', 'https://www.instagram.com/googledeepmind', 'https://www.linkedin.com/company/googledeepmind/', 'https://www.youtube.com/@google_deepmind', 'https://github.com/google-deepmind', 'https://policies.google.com/privacy', 'https://www.google.com/', 'https://about.google/', 'https://about.google/products/', 'https://policies.google.com/privacy', 'https://policies.google.com/terms']

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By

# Set up the options for the Chrome WebDriver
chrome_options = Options()
chrome_options.add_argument("--headless")  # Run Chrome in headless mode (no GUI)

# Create a new instance of the Chrome WebDriver
driver = webdriver.Chrome(options=chrome_options)

# URL of the webpage
url = "https://www.youtube.com/"

# Open the webpage
driver.get(url)

# Wait for the page to load (you might need to adjust the time based on your internet speed)
driver.implicitly_wait(10)

# Get all links from the page
all_links_elements = driver.find_elements(By.TAG_NAME, "a")

# Extract href attributes from the links
all_links = [link.get_attribute("href") for link in all_links_elements]

# Print or use the links as needed
print(all_links)

# Close the WebDriver
driver.quit()
# Out:
# [None, None, 'https://www.youtube.com/', None, 'https://accounts.google.com/ServiceLogin?service=youtube&uilel=3&passive=true&continue=https%3A%2F%2Fwww.youtube.com%2Fsignin%3Faction_handle_signin%3Dtrue%26app%3Ddesktop%26hl%3Dbn%26next%3Dhttps%253A%252F%252Fwww.youtube.com%252F&hl=bn&ec=65620', 'https://www.youtube.com/', 'https://www.youtube.com/', None, 'https://www.youtube.com/feed/subscriptions', 'https://www.youtube.com/feed/you', 'https://www.youtube.com/feed/history', 'https://www.youtube.com/musicpremium/family?ybp=IgoIBBIGZmFtaWx5KhRkaHAtYWNxLW0tQXVnMjBGUHNvZTocCAYYASoWChRkaHAtYWNxLW0tQXVnMjBGUHNvZToCCAhKFQgGEhF1bmxpbWl0ZWQtQi1tdXNpYw%253D%253D', 'https://www.youtube.com/watch?v=m6SqE_Sf0Zw', 'https://www.youtube.com/watch?v=m6SqE_Sf0Zw', 'https://www.youtube.com/@HotlinenewsBD', 'https://www.youtube.com/watch?v=m6SqE_Sf0Zw', 'https://www.youtube.com/@HotlinenewsBD', 'https://www.youtube.com/watch?v=cd5GO4zuGrY', 'https://www.youtube.com/watch?v=cd5GO4zuGrY', 'https://www.youtube.com/@GollachutDrama', 'https://www.youtube.com/watch?v=cd5GO4zuGrY', 'https://www.youtube.com/@GollachutDrama', 'https://www.youtube.com/watch?v=j2C2BPaRccc', 'https://www.youtube.com/watch?v=j2C2BPaRccc', 'https://www.youtube.com/@ATNBanglanews', 'https://www.youtube.com/watch?v=j2C2BPaRccc', 'https://www.youtube.com/@ATNBanglanews', 'https://www.youtube.com/watch?